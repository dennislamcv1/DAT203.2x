# %%
import pandas as pd

from pycaret.classification import *

pd.set_option('display.max_columns',50)

# %%
df = pd.read_csv('Diabetes Classification.csv')

# %%
df
# Out:
#                    race  gender      age   weight  discharge_disposition_id  \
# 0             Caucasian  Female   [0-10)  unknown                        25
# 1             Caucasian  Female  [10-20)  unknown                         1
# 2       AfricanAmerican  Female  [20-30)  unknown                         1
# 3             Caucasian    Male  [30-40)  unknown                         1
# 4             Caucasian    Male  [40-50)  unknown                         1
# ...                 ...     ...      ...      ...                       ...
# 101761  AfricanAmerican    Male  [70-80)  unknown                         3
# 101762  AfricanAmerican  Female  [80-90)  unknown                         4
# 101763        Caucasian    Male  [70-80)  unknown                         1
# 101764        Caucasian  Female  [80-90)  unknown                         3
# 101765        Caucasian    Male  [70-80)  unknown                         1
#
# ...

# %%
df.shape
# Out:
# (101766, 48)

# %%
df.describe()
# Out:
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    4.000000             7.000000          6.000000
# max                   28.000000            25.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count       101766.000000   101766.000000    101766.000000      101766.000000
# mean            43.095641        1.339730        16.021844           0.369357
# std             19.674362        1.705807         8.127566           1.267265
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 48 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   race                        101766 non-null  object
#  1   gender                      101766 non-null  object
#  2   age                         101766 non-null  object
#  3   weight                      101766 non-null  object
#  4   discharge_disposition_id    101766 non-null  int64
#  5   admission_source_id         101766 non-null  int64
#  6   time_in_hospital            101766 non-null  int64
#  7   payer_code                  101766 non-null  object
#  8   medical_specialty           101766 non-null  object
#  9   num_lab_procedures          101766 non-null  int64
#  10  num_procedures              101766 non-null  int64
#  11  num_medications             101766 non-null  int64
#  12  number_outpatient           101766 non-null  int64
# ...

# %% [markdown]
# ### Drop columns

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'weight', 'discharge_disposition_id',
#        'admission_source_id', 'time_in_hospital', 'payer_code',
#        'medical_specialty', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses',
#        'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose',
#        'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton',
#        'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted',
#        'admission_type_description'],
#       dtype='object')

# %%
df
# Out:
#                    race  gender      age   weight  discharge_disposition_id  \
# 0             Caucasian  Female   [0-10)  unknown                        25
# 1             Caucasian  Female  [10-20)  unknown                         1
# 2       AfricanAmerican  Female  [20-30)  unknown                         1
# 3             Caucasian    Male  [30-40)  unknown                         1
# 4             Caucasian    Male  [40-50)  unknown                         1
# ...                 ...     ...      ...      ...                       ...
# 101761  AfricanAmerican    Male  [70-80)  unknown                         3
# 101762  AfricanAmerican  Female  [80-90)  unknown                         4
# 101763        Caucasian    Male  [70-80)  unknown                         1
# 101764        Caucasian  Female  [80-90)  unknown                         3
# 101765        Caucasian    Male  [70-80)  unknown                         1
#
# ...

# %%
df1 = df.drop(['age', 'weight','payer_code','medical_specialty','admission_type_description'],axis=1)

# %%
df1
# Out:
#                    race  gender  discharge_disposition_id  \
# 0             Caucasian  Female                        25
# 1             Caucasian  Female                         1
# 2       AfricanAmerican  Female                         1
# 3             Caucasian    Male                         1
# 4             Caucasian    Male                         1
# ...                 ...     ...                       ...
# 101761  AfricanAmerican    Male                         3
# 101762  AfricanAmerican  Female                         4
# 101763        Caucasian    Male                         1
# 101764        Caucasian  Female                         3
# 101765        Caucasian    Male                         1
#
#         admission_source_id  time_in_hospital  num_lab_procedures  \
# 0                         1                 1                  41
# 1                         7                 3                  59
# 2                         7                 2                  11
# ...

# %%
df1.describe()
# Out:
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    4.000000             7.000000          6.000000
# max                   28.000000            25.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count       101766.000000   101766.000000    101766.000000      101766.000000
# mean            43.095641        1.339730        16.021844           0.369357
# std             19.674362        1.705807         8.127566           1.267265
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      101766 non-null  object
#  1   gender                    101766 non-null  object
#  2   discharge_disposition_id  101766 non-null  int64
#  3   admission_source_id       101766 non-null  int64
#  4   time_in_hospital          101766 non-null  int64
#  5   num_lab_procedures        101766 non-null  int64
#  6   num_procedures            101766 non-null  int64
#  7   num_medications           101766 non-null  int64
#  8   number_outpatient         101766 non-null  int64
#  9   number_emergency          101766 non-null  int64
#  10  number_inpatient          101766 non-null  int64
#  11  diag_1                    101766 non-null  object
#  12  diag_2                    101766 non-null  object
# ...

# %% [markdown]
# ### Setup the Experiment

# %%
exp = setup(data=df1, target= 'readmitted', session_id=123, train_size=0.6, normalize=True)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_248d64ac_baca_11ea_baf0_3c528213d836row15_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_248d64ac_baca_11ea_baf0_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_248d64ac_baca_11ea_baf0_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_248d64ac_baca_11ea_baf0_3c528213d836row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_248d64ac_baca_11ea_baf0_3c528213d836row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_248d64ac_baca_11ea_baf0_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_92192a26_baca_11ea_a00f_3c528213d836 th {
#           text-align: left;
#     }    #T_92192a26_baca_11ea_a00f_3c528213d836row0_col0 {
#             text-align:  left;
#         }    #T_92192a26_baca_11ea_a00f_3c528213d836row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_92192a26_baca_11ea_a00f_3c528213d836row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_92192a26_baca_11ea_a00f_3c528213d836row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_92192a26_baca_11ea_a00f_3c528213d836row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_92192a26_baca_11ea_a00f_3c528213d836row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_92192a26_baca_11ea_a00f_3c528213d836row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...
